# %% [markdown]
# Author: Zhengxiang (Jack) Wang <br>
# Date: 2021-06-22 <br>
# GitHub: https://github.com/jaaack-wang <br>
# About: The current scripts scrapes Chinese Names from http://www.resgain.net/xmdq.html <br>

# %%
import requests
import re
from bs4 import BeautifulSoup as bs
from threading import Thread
from time import time

# %%
def getHTML(url, headers=None):
    '''
    Paras:
        url: str --> a url link
        headers: settings for headers in dict format. By default = None.
    Returns: the html content of a url; or False if the url is invalid. 
    '''
    r = requests.get(url, headers=headers)
    if r.status_code == 200:
        return r.content
    else:
        print(f'【{url}】 is not working!')
        return False

    
def getMetaData(url, headers=None):
    '''
    Returns the following three lists:
        1. Chinese last names
        2. Counts of different full names associated with the last names
        3. The links to full names associated with the last names
    '''
    html = getHTML(url, headers=headers)
    if html:
        soup = bs(html, 'lxml')
        names = soup.select('body > div.main_ > div > div > div > a')
        lastNames = []
        counts = []
        links = []
        for name in names:
            ln = re.search(r'.+(?=姓名字大全)', name.string)
            lastNames.append(ln.group())
            cts = re.search(r'\d+', name['title']).group()
            counts.append(int(cts))
            links.append('http:' + name['href'])
        return lastNames, counts, links        


def getNameLinksByGender(lname_link):
    '''
    Generates all the possible links to names related to a specific last name by gender.
    It turns out that for each name category, there are at most 18 webpages available even when 
    the number of full names related to a last name is much larger than that. One way to get as 
    many names as possible is thus to get full names by gender. 
    ----------------
    Paras:
        lname_link: a link related to a last name extracted from getMetaData
    Return: two list of links of two genders
    '''
    boy = lname_link.replace('_list', '/boys_{}')
    girl = lname_link.replace('_list', '/girls_{}')
    boy_links = []
    girl_links = []
    for i in range(1, 19):
        boy_links.append(boy.format(i))
        girl_links.append(girl.format(i))

    return boy_links, girl_links
    


def getFullNames(urls, headers=None):
    '''
    Paras: 
        urls: list --> a list of urls
    Returns:
        list --> a list of full names in given webpages.   
    '''
    fullnames = []
    for url in urls:
        html = getHTML(url, headers=headers)
        if html:
            soup = bs(html, 'lxml')
            names = soup.select('body > div.main_ > div > div > div > div')
            fullnames.extend([name.div.string for name in names[:-1]])
            
    return fullnames
    

def getFirstNames(fullName, lastName):
    '''
    Works for names where last name comes first and there is no space
    between the first name and the last name. 
    ----------------
    Paras:
        fullName: str or list
        lastName: str
    ----------------
    Return:
        firstNames: str or list
    '''
    firstName = lambda fullName, lastName: fullName[len(lastName):]
    if isinstance(fullName, list):
        return list(map(firstName, fullName, [lastName] * len(fullName)))
    
    elif isinstance(fullName, str):
        return firstName(fullName, lastName)
    
    else:
        raise ValueError('fullName should be either list or str')


def nameInfoWriter(lname, lname_link, writer, template):
    '''
    Write the following information into a file：
        1. Last Name
        2. First Name
        3. Full Name
        4. Gender
    Paras:
        lname: str --> last name
        lname_link: str --> link related to the last name
        writer: f = open(filename, 'w')
        template: formatted string for writing a file
    '''
    boy_links, girl_links = getNameLinksByGender(lname_link)
    # get male's first names and full names
    boy_fullnames = getFullNames(boy_links)
    boy_firstnames = getFirstNames(boy_fullnames, lname)
    # get female's first names and full names
    girl_fullnames = getFullNames(girl_links)
    girl_firstnames = getFirstNames(girl_fullnames, lname)
    
    # -------writing name info----------
    f = writer
    # writing male's name info
    for i in range(len(boy_fullnames)):
        f.write('\n')
        f.write(template.format(lname, boy_firstnames[i], boy_fullnames[i], 'M'))
    # writing female's name info
    for i in range(len(girl_fullnames)):
        f.write('\n')
        f.write(template.format(lname, girl_firstnames[i], girl_fullnames[i], 'F'))
    print(f'Finish writing name info related to {lname}...')

# %%
def main():
    url = 'http://www.resgain.net/xmdq.html'
    # Get the last names, counts of unique full names related with the last times, and the links
    lastNames, counts, links = getMetaData(url)
    # 中国人名信息库 = Chinese Name Info Corpus
    f = open('中国人名信息库.txt', 'w')
    template = '{}\t{}\t{}\t{}'
    f.write(template.format('姓', '名', '全名', '性别'))
    end_idx = len(lastNames)
    for i in range(0, end_idx, 10):
        # multithreading conducted batch by batch to avoid losing connections 
        threads = []
        for idx in range(i, i + 10 if i+10<=end_idx else end_idx):
            t = Thread(target=nameInfoWriter, args=(lastNames[idx], links[idx], f, template,))
            t.start()
            threads.append(t)
        for t in threads:
            t.join()
    f.close()
    
    # writing the metadata
    template = '{}\t{}\t{}'
    # 元数据 = metadata
    with open('元数据.txt', 'w') as f:
        f.write(template.format('姓', '姓名数', '链接'))
        for i in range(len(lastNames)):
            f.write('\n')
            f.write(template.format(lastNames[i], counts[i], links[i]))
        f.close()

# %%
if __name__ == '__main__':
    s = time()
    main()
    e = time()
    print("Total time: " + str(e - s))
# Out:
# Finish writing name info related to 陈...
# Finish writing name info related to 王...
# Finish writing name info related to 李...
# Finish writing name info related to 钱...
# Finish writing name info related to 冯...
# Finish writing name info related to 郑...
# Finish writing name info related to 吴...
# Finish writing name info related to 孙...
# Finish writing name info related to 赵...
# Finish writing name info related to 周...
# Finish writing name info related to 卫...
# Finish writing name info related to 褚...
# Finish writing name info related to 尤...
# Finish writing name info related to 韩...
# Finish writing name info related to 蒋...
# Finish writing name info related to 秦...
# Finish writing name info related to 杨...
# Finish writing name info related to 沈...
# Finish writing name info related to 许...
# Finish writing name info related to 朱...
# Finish writing name info related to 华...
# Finish writing name info related to 张...
# Finish writing name info related to 孔...
# Finish writing name info related to 曹...
# Finish writing name info related to 严...
# Finish writing name info related to 施...Finish writing name info related to 吕...
#
# Finish writing name info related to 何...
# Finish writing name info related to 金...
# Finish writing name info related to 魏...
# Finish writing name info related to 水...
# Finish writing name info related to 柏...
# Finish writing name info related to 窦...
# Finish writing name info related to 喻...
# Finish writing name info related to 戚...
# Finish writing name info related to 章...
# Finish writing name info related to 姜...
# Finish writing name info related to 陶...
# Finish writing name info related to 谢...
# Finish writing name info related to 邹...
# Finish writing name info related to 云...
# Finish writing name info related to 郎...
# Finish writing name info related to 奚...
# Finish writing name info related to 鲁...
# Finish writing name info related to 彭...
# Finish writing name info related to 范...
# Finish writing name info related to 苏...
# Finish writing name info related to 潘...
# Finish writing name info related to 韦...
# Finish writing name info related to 葛...
# Finish writing name info related to 凤...
# Finish writing name info related to 昌...
# Finish writing name info related to 花...
# Finish writing name info related to 苗...
# Finish writing name info related to 柳...
# Finish writing name info related to 俞...
# Finish writing name info related to 袁...
# Finish writing name info related to 方...
# Finish writing name info related to 任...
# Finish writing name info related to 马...
# Finish writing name info related to 廉...
# Finish writing name info related to 酆...
# Finish writing name info related to 岑...
# Finish writing name info related to 费...
# Finish writing name info related to 贺...
# Finish writing name info related to 雷...
# Finish writing name info related to 史...
# Finish writing name info related to 鲍...
# Finish writing name info related to 唐...
# Finish writing name info related to 薛...
# Finish writing name info related to 邬...
# Finish writing name info related to 滕...
# Finish writing name info related to 殷...
# Finish writing name info related to 汤...
# Finish writing name info related to 倪...
# Finish writing name info related to 毕...
# Finish writing name info related to 常...
# Finish writing name info related to 安...
# Finish writing name info related to 郝...
# Finish writing name info related to 罗...
# Finish writing name info related to 皮...
# Finish writing name info related to 乐...
# Finish writing name info related to 卞...
# Finish writing name info related to 时...
# Finish writing name info related to 齐...
# Finish writing name info related to 余...
# Finish writing name info related to 伍...
# Finish writing name info related to 傅...
# Finish writing name info related to 康...
# Finish writing name info related to 于...
# Finish writing name info related to 元...
# Finish writing name info related to 平...
# Finish writing name info related to 和...
# Finish writing name info related to 卜...
# Finish writing name info related to 穆...
# Finish writing name info related to 萧...
# Finish writing name info related to 孟...
# Finish writing name info related to 尹...
# Finish writing name info related to 顾...
# Finish writing name info related to 黄...
# Finish writing name info related to 贝...
# Finish writing name info related to 湛...
# Finish writing name info related to 禹...
# Finish writing name info related to 狄...
# Finish writing name info related to 米...
# Finish writing name info related to 祁...
# Finish writing name info related to 毛...
# Finish writing name info related to 汪...
# Finish writing name info related to 姚...
# Finish writing name info related to 邵...
# Finish writing name info related to 伏...
# Finish writing name info related to 茅...
# Finish writing name info related to 计...
# Finish writing name info related to 明...
# Finish writing name info related to 谈...
# Finish writing name info related to 臧...
# Finish writing name info related to 成...
# Finish writing name info related to 庞...
# Finish writing name info related to 戴...
# Finish writing name info related to 宋...
# Finish writing name info related to 项...
# Finish writing name info related to 舒...
# Finish writing name info related to 阮...
# Finish writing name info related to 屈...
# Finish writing name info related to 纪...
# Finish writing name info related to 董...
# Finish writing name info related to 梁...
# Finish writing name info related to 祝...
# Finish writing name info related to 杜...
# Finish writing name info related to 熊...
# Finish writing name info related to 危...
# Finish writing name info related to 强...
# Finish writing name info related to 麻...
# Finish writing name info related to 闵...
# Finish writing name info related to 席...
# Finish writing name info related to 娄...
# Finish writing name info related to 路...
# Finish writing name info related to 蓝...
# Finish writing name info related to 贾...
# Finish writing name info related to 季...
# Finish writing name info related to 刁...
# Finish writing name info related to 童...
# Finish writing name info related to 盛...
# Finish writing name info related to 梅...
# Finish writing name info related to 颜...
# Finish writing name info related to 钟...
# Finish writing name info related to 江...
# Finish writing name info related to 郭...
# Finish writing name info related to 林...
# Finish writing name info related to 徐...
# Finish writing name info related to 霍...
# Finish writing name info related to 凌...
# Finish writing name info related to 骆...
# Finish writing name info related to 樊...
# Finish writing name info related to 夏...
# Finish writing name info related to 邱...
# Finish writing name info related to 蔡...
# Finish writing name info related to 田...
# Finish writing name info related to 高...
# Finish writing name info related to 胡...
# Finish writing name info related to 昝...
# Finish writing name info related to 支...
# Finish writing name info related to 裘...
# Finish writing name info related to 房...
# Finish writing name info related to 虞...
# Finish writing name info related to 柯...
# Finish writing name info related to 管...
# Finish writing name info related to 莫...
# Finish writing name info related to 万...
# Finish writing name info related to 卢...
# Finish writing name info related to 贲...
# Finish writing name info related to 干...
# Finish writing name info related to 宣...
# Finish writing name info related to 郁...
# Finish writing name info related to 宗...
# Finish writing name info related to 缪...
# Finish writing name info related to 解...
# Finish writing name info related to 应...
# Finish writing name info related to 邓...
# Finish writing name info related to 丁...
# Finish writing name info related to 钮...
# Finish writing name info related to 杭...
# Finish writing name info related to 诸...
# Finish writing name info related to 吉...
# Finish writing name info related to 包...
# Finish writing name info related to 洪...
# Finish writing name info related to 单...
# Finish writing name info related to 崔...
# Finish writing name info related to 石...
# Finish writing name info related to 左...
# Finish writing name info related to 滑...
# Finish writing name info related to 荀...
# Finish writing name info related to 嵇...
# Finish writing name info related to 荣...
# Finish writing name info related to 裴...
# Finish writing name info related to 龚...
# Finish writing name info related to 翁...
# Finish writing name info related to 陆...
# Finish writing name info related to 程...
# Finish writing name info related to 邢...
# Finish writing name info related to 羿...
# Finish writing name info related to 羊...
# Finish writing name info related to 芮...
# Finish writing name info related to 家...
# Finish writing name info related to 储...
# Finish writing name info related to 惠...
# Finish writing name info related to 甄...
# Finish writing name info related to 封...
# Finish writing name info related to 曲...
# Finish writing name info related to 靳...
# Finish writing name info related to 乌...
# Finish writing name info related to 糜...
# Finish writing name info related to 汲...
# Finish writing name info related to 邴...
# Finish writing name info related to 富...
# Finish writing name info related to 松...
# Finish writing name info related to 井...
# Finish writing name info related to 巫...
# Finish writing name info related to 焦...
# Finish writing name info related to 段...
# Finish writing name info related to 弓...
# Finish writing name info related to 宓...
# Finish writing name info related to 山...
# Finish writing name info related to 巴...
# Finish writing name info related to 牧...
# Finish writing name info related to 蓬...
# Finish writing name info related to 隗...
# Finish writing name info related to 车...
# Finish writing name info related to 侯...
# Finish writing name info related to 谷...
# Finish writing name info related to 郗...
# Finish writing name info related to 班...
# Finish writing name info related to 仰...
# Finish writing name info related to 秋...
# Finish writing name info related to 伊...
# Finish writing name info related to 仲...
# Finish writing name info related to 全...
# Finish writing name info related to 仇...
# Finish writing name info related to 宫...
# Finish writing name info related to 宁...
# Finish writing name info related to 钭...
# Finish writing name info related to 暴...
# Finish writing name info related to 戎...
# Finish writing name info related to 祖...
# Finish writing name info related to 历...
# Finish writing name info related to 栾...
# Finish writing name info related to 符...
# Finish writing name info related to 刘...
# Finish writing name info related to 甘...
# Finish writing name info related to 武...
# Finish writing name info related to 韶...
# Finish writing name info related to 束...
# Finish writing name info related to 幸...
# Finish writing name info related to 郜...
# Finish writing name info related to 景...
# Finish writing name info related to 司...
# Finish writing name info related to 詹...
# Finish writing name info related to 龙...
# Finish writing name info related to 黎...
# Finish writing name info related to 叶...
# Finish writing name info related to 怀...
# Finish writing name info related to 邰...
# Finish writing name info related to 从...
# Finish writing name info related to 鄂...
# Finish writing name info related to 印...
# Finish writing name info related to 宿...
# Finish writing name info related to 蓟...
# Finish writing name info related to 溥...
# Finish writing name info related to 蒲...
# Finish writing name info related to 白...
# Finish writing name info related to 咸...
# Finish writing name info related to 索...
# Finish writing name info related to 籍...
# Finish writing name info related to 蔺...
# Finish writing name info related to 屠...
# Finish writing name info related to 池...
# Finish writing name info related to 蒙...
# Finish writing name info related to 卓...
# Finish writing name info related to 乔...
# Finish writing name info related to 赖...
# Finish writing name info related to 能...
# Finish writing name info related to 苍...
# Finish writing name info related to 双...
# Finish writing name info related to 闻...
# Finish writing name info related to 莘...
# Finish writing name info related to 胥...
# Finish writing name info related to 阳...
# Finish writing name info related to 党...
# Finish writing name info related to 翟...
# Finish writing name info related to 谭...
# Finish writing name info related to 宰...
# Finish writing name info related to 堵...
# Finish writing name info related to 扶...
# Finish writing name info related to 郦...
# Finish writing name info related to 贡...
# Finish writing name info related to 逄...
# Finish writing name info related to 劳...
# Finish writing name info related to 姬...
# Finish writing name info related to 冉...
# Finish writing name info related to 申...
# Finish writing name info related to 通...
# Finish writing name info related to 璩...
# Finish writing name info related to 濮...
# Finish writing name info related to 寿...
# Finish writing name info related to 雍...
# Finish writing name info related to 却...
# Finish writing name info related to 桑...
# Finish writing name info related to 桂...
# Finish writing name info related to 边...
# Finish writing name info related to 牛...
# Finish writing name info related to 浦...
# Finish writing name info related to 扈...
# Finish writing name info related to 别...
# Finish writing name info related to 冀...
# Finish writing name info related to 燕...
# Finish writing name info related to 晏...
# Finish writing name info related to 农...
# Finish writing name info related to 尚...
# Finish writing name info related to 温...
# Finish writing name info related to 庄...
# Finish writing name info related to 充...
# Finish writing name info related to 宦...
# Finish writing name info related to 习...
# Finish writing name info related to 慕...
# Finish writing name info related to 茹...
# Finish writing name info related to 瞿...
# Finish writing name info related to 连...
# Finish writing name info related to 阎...
# Finish writing name info related to 艾...
# Finish writing name info related to 柴...
# Finish writing name info related to 鱼...
# Finish writing name info related to 慎...
# Finish writing name info related to 戈...
# Finish writing name info related to 容...
# Finish writing name info related to 终...
# Finish writing name info related to 庾...
# Finish writing name info related to 古...
# Finish writing name info related to 向...
# Finish writing name info related to 易...
# Finish writing name info related to 廖...
# Finish writing name info related to 衡...
# Finish writing name info related to 步...
# Finish writing name info related to 居...
# Finish writing name info related to 都...
# Finish writing name info related to 满...
# Finish writing name info related to 国...
# Finish writing name info related to 暨...
# Finish writing name info related to 弘...
# Finish writing name info related to 匡...
# Finish writing name info related to 耿...
# Finish writing name info related to 殳...
# Finish writing name info related to 禄...
# Finish writing name info related to 广...
# Finish writing name info related to 沃...
# Finish writing name info related to 东...
# Finish writing name info related to 利...
# Finish writing name info related to 阙...
# Finish writing name info related to 寇...
# Finish writing name info related to 欧...
# Finish writing name info related to 文...
# Finish writing name info related to 厍...
# Finish writing name info related to 蔚...
# Finish writing name info related to 勾...
# Finish writing name info related to 晁...
# Finish writing name info related to 隆...
# Finish writing name info related to 越...
# Finish writing name info related to 夔...
# Finish writing name info related to 巩...
# Finish writing name info related to 师...
# Finish writing name info related to 聂...
# Finish writing name info related to 空...
# Finish writing name info related to 那...
# Finish writing name info related to 融...
# Finish writing name info related to 阚...
# Finish writing name info related to 訾...
# Finish writing name info related to 敖...
# Finish writing name info related to 简...
# Finish writing name info related to 冷...
# Finish writing name info related to 饶...
# Finish writing name info related to 辛...
# Finish writing name info related to 乜...
# Finish writing name info related to 须...
# Finish writing name info related to 毋...
# Finish writing name info related to 巢...
# Finish writing name info related to 丰...
# Finish writing name info related to 养...
# Finish writing name info related to 鞠...
# Finish writing name info related to 沙...
# Finish writing name info related to 关...
# Finish writing name info related to 曾...
# Finish writing name info related to 后...
# Finish writing name info related to 蒯...
# Finish writing name info related to 竺...
# Finish writing name info related to 逮...
# Finish writing name info related to 相...
# Finish writing name info related to 权...
# Finish writing name info related to 红...
# Finish writing name info related to 查...
# Finish writing name info related to 荆...
# Finish writing name info related to 游...
# Finish writing name info related to 闻人...
# Finish writing name info related to 桓...
# Finish writing name info related to 司马...
# Finish writing name info related to 夏侯...
# Finish writing name info related to 益...
# Finish writing name info related to 公...
# Finish writing name info related to 上官...
# Finish writing name info related to 诸葛...
# Finish writing name info related to 万俟...
# Finish writing name info related to 欧阳...
# Finish writing name info related to 赫连...
# Finish writing name info related to 澹台...
# Finish writing name info related to 尉迟...
# Finish writing name info related to 公冶...
# Finish writing name info related to 皇甫...
# Finish writing name info related to 东方...
# Finish writing name info related to 宗政...
# Finish writing name info related to 公羊...
# Finish writing name info related to 濮阳...
# Finish writing name info related to 淳于...
# Finish writing name info related to 令狐...
# Finish writing name info related to 轩辕...
# Finish writing name info related to 宇文...
# Finish writing name info related to 申屠...
# Finish writing name info related to 太叔...
# Finish writing name info related to 徐离...
# Finish writing name info related to 单于...
# Finish writing name info related to 公孙...
# Finish writing name info related to 长孙...
# Finish writing name info related to 仲孙...
# Finish writing name info related to 慕容...
# Finish writing name info related to 司徒...
# Finish writing name info related to 司空...
# Finish writing name info related to 楼...
# Finish writing name info related to 楚...
# Total time: 3367.6042499542236

# %%
with open('Chinese_Names.txt', 'a') as f:
    f.write(open('../中国人名语料库.txt', 'r').read())
    f.close()
